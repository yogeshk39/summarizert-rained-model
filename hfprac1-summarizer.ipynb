# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("summarization", model="slauw87/bart_summarisation")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/300 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("slauw87/bart_summarisation")
model = AutoModelForSeq2SeqLM.from_pretrained("slauw87/bart_summarisation")

# %%
def summarize_text(text):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", max_length=1024, truncation=True)

    # Generate the summary
    summary_ids = model.generate(inputs.input_ids, num_beams=4, max_length=150, early_stopping=True)

    # Decode the generated summary
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

# %%
text = """
The industrial revolution, which took place from the 18th to 19th centuries, was a period during which predominantly agrarian, rural societies in Europe and America became industrial and urban. Prior to the Industrial Revolution, which began in Britain in the late 1700s, manufacturing was often done in people’s homes, using hand tools or basic machines. Industrialization marked a shift to powered, special-purpose machinery, factories, and mass production. The iron and textile industries, along with the development of the steam engine, played central roles in the Industrial Revolution, which also saw improved systems of transportation, communication, and banking. While industrialization brought about an increased volume and variety of manufactured goods and an improved standard of living for some, it also resulted in often grim employment and living conditions for the poor and working classes.

The Industrial Revolution brought about significant changes in the way goods were produced and the methods by which people lived and worked. The development of steam power and the rise of factories provided a boost to numerous industries including textiles, iron production, and coal mining. With steam engines and powered machinery, production processes became more efficient and capable of producing goods on a larger scale than ever before. This period also saw the rise of the factory system, where workers were employed in large-scale production facilities that centralized production in a single location. This was in contrast to the previous system of craft production, where individual artisans would produce goods by hand in their own workshops.

The growth of factories also led to a migration of people from rural areas to urban centers in search of work. Cities like Manchester, Birmingham, and Liverpool experienced rapid population growth as people moved to be closer to the new factories and job opportunities. This urbanization had a profound impact on society, leading to the development of new social classes and changing family structures. While the middle class benefited from the new economic opportunities, the working class often faced difficult working conditions with long hours, low wages, and little job security. Child labor was also a significant issue during this period, with many children working in factories and mines under hazardous conditions.

The Industrial Revolution also had a significant impact on the environment. The rise of factories and increased use of coal and other fossil fuels led to significant air and water pollution. The growth of cities also resulted in the development of slums and poor living conditions for many urban residents. Despite these challenges, the Industrial Revolution laid the groundwork for many of the technological advances and economic developments that would follow in the 19th and 20th centuries. It also sparked a wave of social and political reforms as people sought to address the negative impacts of industrialization and improve living and working conditions.

As the Industrial Revolution progressed, there were significant technological innovations that changed the face of manufacturing. The development of the spinning jenny, the power loom, and the cotton gin revolutionized the textile industry, making it possible to produce cloth more quickly and cheaply. In the iron industry, the invention of the blast furnace and the Bessemer process allowed for the mass production of steel, which became a crucial material for building infrastructure and machinery. The introduction of the steam engine was perhaps the most significant development, as it provided a new source of power that could be used in a variety of industries. Steam engines were used to power factories, mines, and transportation systems, including railways and steamships.

The impact of the Industrial Revolution was felt across the globe. As European countries industrialized, they sought new markets and resources, leading to an era of colonial expansion. This period saw the spread of industrialization to other parts of the world, including the United States, Japan, and parts of Europe. The global impact of the Industrial Revolution also included the spread of new ideas and technologies, which helped to shape the modern world. While the Industrial Revolution brought about many positive changes, it also highlighted the need for social and political reforms to address the negative consequences of industrialization.

In conclusion, the Industrial Revolution was a transformative period in history that changed the way goods were produced and the way people lived and worked. It brought about significant technological advancements and economic growth, but also presented challenges such as poor working conditions, environmental pollution, and social inequality. The legacy of the Industrial Revolution can still be seen today in the continued development of technology and industry, as well as ongoing efforts to address the social and environmental impacts of industrialization.
"""

summary = summarize_text(text)
print("Summary:", summary)
# Out:
# Summary: The Industrial Revolution took place from the 18th to 19th centuries. It was a period during which predominantly agrarian, rural societies in Europe and America became industrial and urban. It brought about significant technological advancements and economic growth, but also presented challenges such as poor working conditions, environmental pollution, and inequality. The impact of the Industrial Revolution was felt across the globe.

# %%
# Step 1: Install the transformers library
# !pip install transformers

# Step 2: Import necessary libraries and load the model and tokenizer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("slauw87/bart_summarisation")
model = AutoModelForSeq2SeqLM.from_pretrained("slauw87/bart_summarisation")

# Step 3: Define the summarization function
def summarize_text(text):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", max_length=1024, truncation=True)

    # Generate the summary
    summary_ids = model.generate(inputs.input_ids, num_beams=4, max_length=150, early_stopping=True)

    # Decode the generated summary
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

# Step 4: Test the summarization function
# Example usage
text = "Your input text goes here. It can be any lengthy text that you want to summarize."
summary = summarize_text(text)
print("Summary:", summary)
# Out:
# ...
# Summary: Your input text goes here. It can be any lengthy text that you want to summarize and can be of any length you want it to be summarised.  .    "I am not satisfied with the sum of this text." is the input text.
